# %%
import yfinance as yf
dat = yf.Ticker("asdfasdf")

# %%
dat.history(period='1mo').tail(7)
# Out:
# HTTP Error 404:
# $ASDFASDF: possibly delisted; no price data found  (period=1mo) (Yahoo error = "No data found, symbol may be delisted")
# Empty DataFrame
# Columns: [Open, High, Low, Close, Adj Close, Volume]
# Index: []

# %%
dat.info['displayName']
# Out:
# 'Tesla'

# %%
# !curl 'https://newsapi.org/v2/everything?q=tesla&from=2025-6-23&to=2025-6-23&sortBy=relevancy&language=en&apiKey=f49d8ab3b85147879b01c72b2efe4bb6'
# Out:
# {"status":"ok","totalResults":631,"articles":[{"source":{"id":"business-insider","name":"Business Insider"},"author":"Hallam Bullock","title":"The US bombed Iran. Now, the whole world is watching the Strait of Hormuz.","description":"All eyes are now on the Strait of Hormuz, a 90-mile strip critical to global oil prices.","url":"https://www.businessinsider.com/iran-bomb-strait-of-hormuz-oil-stock-markets-israel-latest-2025-6","urlToImage":"https://i.insider.com/685936453d5881a51c1bdc27?width=1200&format=jpeg","publishedAt":"2025-06-23T12:17:51Z","content":"Fishing and cargo container ships sailing in the Strait of Hormuz in 2019.Germán Vogel/Getty Images\r\n<ul><li>This post originally appeared in the Business Insider Today newsletter.</li><li>You can si… [+7356 chars]"},{"source":{"id":null,"name":"TheStreet"},"author":"Anand Sinha","title":"Billionaire stuns Elon Musk with shocking question after Tesla robotaxi rollout","description":"Elon Musk's Tesla rolls out driverless robotaxi
# ...
